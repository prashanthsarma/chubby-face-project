# %%
def get_degrees(sign):
    signs = {
        "Aries": 0,
        "Taurus": 30,
        "Gemini": 60,
        "Cancer": 90,
        "Leo": 120,
        "Virgo": 150,
        "Libra": 180,
        "Scorpio": 210,
        "Sagittarius": 240,
        "Capricorn": 270,
        "Aquarius": 300,
        "Pisces": 330
    }
    return signs[sign]
plant_exalt = {
     "Sun": 10, "Moon": 33, "Mars": 298, "Mercury": 165, "Jupiter": 95, "Venus": 357, "Saturn": 200
}
planet_signs = {
    "Sun": {
        "exalted": 10,
        "moola_trikona": [120, 140],
        "own_sign": ["Leo"],
        "friendly_sign": ["Aries", "Cancer", "Scorpio", "Sagittarius", "Pisces"],
        "neutral_sign": ["Gemini", "Virgo"],
        "enemy_sign": ["Taurus", "Libra", "Capricorn", "Aquarius"]
    },
    "Moon": {
        "exalted": 33,
        "moola_trikona": [33, 50],
        "own_sign": ["Cancer"],
        "friendly_sign": ["Gemini", "Leo", "Virgo"],
        "neutral_sign": ["Aries", "Scorpio", "Sagittarius", "Pisces","Libra", "Capricorn", "Aquarius"],
        "enemy_sign": []
    },
    "Mars": {
        "exalted": 298,
        "moola_trikona": [0, 12],
        "own_sign": ["Aries", "Scorpio"],
        "friendly_sign": ["Leo", "Cancer", "Sagittarius", "Pisces"],
        "neutral_sign": ["Taurus", "Libra", "Capricorn", "Aquarius"],
        "enemy_sign": ["Gemini", "Virgo"]
    },
    "Mercury": {
        "exalted": 165,
        "moola_trikona": [165, 170],
        "own_sign": ["Gemini", "Virgo"],
        "friendly_sign": ["Leo", "Taurus", "Libra"],
        "neutral_sign": ["Cancer"],
        "enemy_sign": ["Aries", "Scorpio", "Sagittarius", "Pisces"]
    },
    "Jupiter": {
        "exalted": 95,
        "moola_trikona": [240, 250],
        "own_sign": ["Sagittarius", "Pisces"],
        "friendly_sign": ["Leo", "Cancer", "Aries", "Scorpio"],
        "neutral_sign": ["Capricorn", "Aquarius"],
        "enemy_sign": ["Taurus", "Gemini", "Virgo", "Libra"]
    },
    "Venus": {
        "exalted": 357,
        "moola_trikona": [180, 195],
        "own_sign": ["Taurus", "Libra"],
        "friendly_sign": ["Sagittarius", "Pisces", "Aries", "Scorpio"],
        "neutral_sign": ["Aries", "Leo", "Sagittarius"],
        "enemy_sign": ["Leo", "Cancer"]
    },
    "Saturn": {
        "exalted": 200,
        "moola_trikona": [300, 320],
        "own_sign": ["Capricorn", "Aquarius"],
        "friendly_sign": ["Taurus", "Gemini", "Virgo", "Libra"],
        "neutral_sign": ["Sagittarius", "Pisces"],
        "enemy_sign": ["Aries","Cancer", "Leo", "Scorpio"]
    }
}

# Convert to 360-degree scale
planet_sign_degrees = {}
for planet, signs in planet_signs.items():
    planet_sign_degrees[planet] = {
        "exalted": signs["exalted"],
        "moola_trikona": signs["moola_trikona"],
        "own_sign": [get_degrees(sign) for sign in signs["own_sign"]],
        "friendly_sign": [get_degrees(sign) for sign in signs["friendly_sign"]],
        "neutral_sign": [get_degrees(sign) for sign in signs["neutral_sign"]],
        "enemy_sign": [get_degrees(sign) for sign in signs["enemy_sign"]]
    }

# Example output for one planet
import pprint
pprint.pprint(planet_sign_degrees)
# Out:
# {'Jupiter': {'enemy_sign': [30, 60, 150, 180],
#              'exalted': 95,
#              'friendly_sign': [120, 90, 0, 210],
#              'moola_trikona': [240, 250],
#              'neutral_sign': [270, 300],
#              'own_sign': [240, 330]},
#  'Mars': {'enemy_sign': [60, 150],
#           'exalted': 298,
#           'friendly_sign': [120, 90, 240, 330],
#           'moola_trikona': [0, 12],
#           'neutral_sign': [30, 180, 270, 300],
#           'own_sign': [0, 210]},
#  'Mercury': {'enemy_sign': [0, 210, 240, 330],
#              'exalted': 165,
#              'friendly_sign': [120, 30, 180],
#              'moola_trikona': [165, 170],
#              'neutral_sign': [90],
#              'own_sign': [60, 150]},
#  'Moon': {'enemy_sign': [],
#           'exalted': 33,
#           'friendly_sign': [60, 120, 150],
#           'moola_trikona': [33, 50],
#           'neutral_sign': [0, 210, 240, 330, 180, 270, 300],
#           'own_sign': [90]},
# ...
